# %%
import pandas as pd
pd.__version__
# Out:
# '1.4.1'

# %%
df_meterorites = pd.read_csv('db/Meteorite_Landings.csv')
df_meterorites
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
df_meterorites.tail(10)
# Out:
#              name     id nametype              recclass   mass (g)   fall  \
# 45706     Zerkaly  31354    Valid                    H5    16000.0  Found
# 45707    Zhaoping  54609    Valid     Iron, IAB complex  2000000.0  Found
# 45708    Zhigansk  30405    Valid           Iron, IIIAB   900000.0  Found
# 45709  Zhongxiang  30406    Valid                  Iron   100000.0  Found
# 45710  Zillah 001  31355    Valid                    L6     1475.0  Found
# 45711  Zillah 002  31356    Valid               Eucrite      172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46.0  Found
# 45713        Zlin  30410    Valid                    H4        3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6     2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200.0  Found
#
#          year    reclat    reclong             GeoLocation
# 45706  1956.0  52.13333   81.96667    (52.13333, 81.96667)
# ...

# %%
df_meterorites.sample(10)
# Out:
#                               name     id nametype recclass  mass (g)   fall  \
# 12531      Frontier Mountain 99023  10816    Valid       H4      0.30  Found
# 18795         LaPaz Icefield 04668  45216    Valid       L6     10.30  Found
# 15990        Hammadah al Hamra 014  11499    Valid       L5     94.00  Found
# 43268                 Yamato 86501  30007    Valid       H4      3.52  Found
# 21463            Lewis Cliff 88741  14478    Valid       H6     27.00  Found
# 32431  Queen Alexandra Range 93176  19265    Valid       L5      2.10  Found
# 17038        Jiddat al Harasis 576  51918    Valid     H5/6    284.60  Found
# 19446        Larkman Nunatak 06607  49661    Valid       L5     27.30  Found
# 7271                   Dhofar 1464  51607    Valid      H~5     68.50  Found
# 23367        Meteorite Hills 00672  15906    Valid       L6      6.82  Found
#
#          year    reclat    reclong             GeoLocation
# 12531  1999.0 -72.99194  160.41111  (-72.99194, 160.41111)
# ...

# %%
df_meterorites.shape
# Out:
# (45716, 10)

# %%
df_meterorites.size
# Out:
# 457160

# %%
pd.options.display.float_format = '{:,.1f}'.format

# %%
df_meterorites.describe()
# Out:
#             id     mass (g)     year   reclat  reclong
# count 45,716.0     45,585.0 45,425.0 38,401.0 38,401.0
# mean  26,889.7     13,278.1  1,991.8    -39.1     61.1
# std   16,860.7    574,988.9     25.1     46.4     80.6
# min        1.0          0.0    860.0    -87.4   -165.4
# 25%   12,688.8          7.2  1,987.0    -76.7      0.0
# 50%   24,261.5         32.6  1,998.0    -71.5     35.7
# 75%   40,656.8        202.6  2,003.0      0.0    157.2
# max   57,458.0 60,000,000.0  2,101.0     81.2    354.5

# %%
df_meterorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.5+ MB

# %%
df_meterorites.convert_dtypes().dtypes
# Out:
# name            string
# id               Int64
# nametype        string
# recclass        string
# mass (g)       Float64
# fall            string
# year             Int64
# reclat         Float64
# reclong        Float64
# GeoLocation     string
# dtype: object

# %%
df_meterorites.nunique()
# Out:
# name           45716
# id             45716
# nametype           2
# recclass         466
# mass (g)       12576
# fall               2
# year             265
# reclat         12738
# reclong        14640
# GeoLocation    17100
# dtype: int64

# %%
df_meterorites[['nametype', 'fall']] = df_meterorites[['nametype', 'fall']].astype('category')
df_meterorites.dtypes
# Out:
# name             object
# id                int64
# nametype       category
# recclass         object
# mass (g)        float64
# fall           category
# year            float64
# reclat          float64
# reclong         float64
# GeoLocation      object
# dtype: object

# %%
df_meterorites['fall'].unique()
# Out:
# ['Fell', 'Found']
# Categories (2, object): ['Fell', 'Found']

# %%
df_meterorites['fall'].value_counts()
# Out:
# Found    44609
# Fell      1107
# Name: fall, dtype: int64

# %%
pd.get_dummies(df_meterorites['fall'])
# Out:
#        Fell  Found
# 0         1      0
# 1         1      0
# 2         1      0
# 3         1      0
# 4         1      0
# ...     ...    ...
# 45711     0      1
# 45712     0      1
# 45713     0      1
# 45714     0      1
# 45715     0      1
#
# [45716 rows x 2 columns]

# %%
df_meterorites[['fell','found']] = pd.get_dummies(df_meterorites['fall'])

# %%
df_meterorites.sample(10)
# Out:
#                               name     id nametype recclass  mass (g)   fall  \
# 29916        Northwest Africa 6501  52872    Valid       L3      93.0  Found
# 22858         MacKay Glacier 05250  36387    Valid       L6      34.9  Found
# 13614       Grove Mountains 020180  47737    Valid       H5       0.6  Found
# 10804       Elephant Moraine 90788   9197    Valid       L6       4.1  Found
# 6413               Dar al Gani 642   6189    Valid       L6     265.0  Found
# 33016  Queen Alexandra Range 94204  19846    Valid      EH7   2,427.9  Found
# 39757                Yamato 790496  25845    Valid       H4       6.8  Found
# 33996  Queen Alexandra Range 97363  20821    Valid      LL5      73.3  Found
# 16023        Hammadah al Hamra 048  11531    Valid     H4/5   1,002.0  Found
# 27041        Northwest Africa 1931  17553    Valid       H5     267.0  Found
#
#          year  reclat  reclong             GeoLocation  fell  found
# ...

# %%
df_meterorites['year']
# Out:
# 0       1,880.0
# 1       1,951.0
# 2       1,952.0
# 3       1,976.0
# 4       1,902.0
#           ...
# 45711   1,990.0
# 45712   1,999.0
# 45713   1,939.0
# 45714   2,003.0
# 45715   1,976.0
# Name: year, Length: 45716, dtype: float64

# %%
df_meterorites.rename(columns={'mass (g)': 'mass'}, inplace=True)

# %%
df_meterorites.head()
# Out:
#        name   id nametype     recclass      mass  fall    year  reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell 1,880.0    50.8
# 1    Aarhus    2    Valid           H6     720.0  Fell 1,951.0    56.2
# 2      Abee    6    Valid          EH4 107,000.0  Fell 1,952.0    54.2
# 3  Acapulco   10    Valid  Acapulcoite   1,914.0  Fell 1,976.0    16.9
# 4   Achiras  370    Valid           L6     780.0  Fell 1,902.0   -33.2
#
#    reclong           GeoLocation  fell  found
# 0      6.1     (50.775, 6.08333)     1      0
# 1     10.2  (56.18333, 10.23333)     1      0
# 2   -113.0    (54.21667, -113.0)     1      0
# 3    -99.9     (16.88333, -99.9)     1      0
# 4    -65.0   (-33.16667, -64.95)     1      0
